# %%
# General
import os
import glob

# Data Analysis
import numpy as np
import pandas as pd

# Visualization
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
unit = "line"
data_dir = 'data/' + unit + '/preprocessed/'
cutoff = 7

# %%
filenames = np.array(glob.glob(data_dir+'*.csv'))
filenames = [f for f in filenames if 'vergil' not in f]
filenames
# Out:
# ['data/line/preprocessed/lucan-ovid-amores.csv',
#  'data/line/preprocessed/lucan-ovid-ars_amatoria.csv',
#  'data/line/preprocessed/lucan-ovid-heroides.csv',
#  'data/line/preprocessed/lucan-ovid-medicamina.csv',
#  'data/line/preprocessed/lucan-ovid-remedia_amoris.csv',
#  'data/line/preprocessed/lucan-propertius-elegies.csv',
#  'data/line/preprocessed/lucan-tibullus-elegies.csv']

# %%
results = pd.DataFrame()

for file in filenames:
    df = pd.read_csv(file)
    results = results.append(df)

results = results.reset_index(drop=True)

results
# Out:
#        RESULT   TARGET_LOC                                         TARGET_TXT  \
# 0           1  luc. 10.429  Est operis: visum famulis **reparabile** **dam...
# 1           2   luc. 2.594  Armenios, **Cilicasque** **feros**, Taurosque ...
# 2           3   luc. 2.612   Cecropiae, victum mentitis **Thesea** **velis**.
# 3           4   luc. 4.457  Huc fractas Aquilone **rates** **submersaque**...
# 4           5   luc. 5.322  Detegit imbelles animos nil **fortiter** **ausa**
# 5           6   luc. 7.420  Possedit, **citius** **per** prospera fata cuc...
# 6           7   luc. 3.107  **Praetor** adest: **vacuaeque** loco cessere ...
# 7           8   luc. 4.224     Eruerent, nulli vallarent **oppida** **muri**,
# 8           9   luc. 6.369  Quique nec humentes nebulas, nec **rore** **ma...
# 9          10   luc. 4.316  tunc herbas frondesque terunt, et **rore** **m...
# 10         11   luc. 1.288  **Livor** **edax** tibi cuncta negat: gentesqu...
# 11         12  luc. 10.135    Vix ulla fuscante **tamen** **lanugine** malas.
# 12         13   luc. 5.497  Ausoniam tu solus habes. His **terque** **quat...
# 13         14   luc. 3.733  Non lacrimae cecidere genis, non **pectora** *...
# 14         15   luc. 3.198  Thracius, et **populum** Pholoe mentita **bifo...
# 15         16   luc. 4.439    Aut **dum** dispositis adtollat **retia** varis
# 16         17   luc. 6.404  Fudit et **argentum** flammis, **aurumque** mo...
# 17         18   luc. 8.869     **Argumenta** **tuae**. Veniet felicior aetas,
# 18         19   luc. 9.962  Et **Simoentis** **aquas**, et Graio nobile busto
# 19         20   luc. 4.637  Ille **suis**. Numquam saevae sperare **noverc...
# 20         21   luc. 4.304  Extrahitur, **duris** **silicum** lassata meta...
# 21         22   luc. 5.806   Insomnis. **Viduo** tum primum **frigida** lecto
# 22         23   luc. 4.451  Et laxas fluitare sinit **religatque** **caten...
# 23         24   luc. 2.671  Roboraque immensis late **religare** **catenis**.
# 24         25   luc. 4.300  Aut micuere novi, percusso **pumice**, **fonte...
# 25         26   luc. 2.674  **Europamque** **Asiae**, Sestonque admovit Ab...
# 26         27   luc. 7.489  Sed **quota** **pars** cladis iaculis ferroque...
# 27         28   luc. 1.284  **Pars** **quota** terrarum! Facili si proelia...
# 28         29   luc. 3.112  **Erubuit**, quam Roma pati. **Tamen** exit in...
# 29         30   luc. 4.358  Degere, **quam** **tribuis**: campis prostrata...
# ...       ...          ...                                                ...
# 62485    6831   luc. 7.134   Adtonitus **maiore** metu. **Quis** litora ponto
# 62486    6832   luc. 4.361  Captos ferre **tui**: turba haec sua **fata** ...
# 62487    6833   luc. 9.638  **Quis** timuit? quem, qui recto se lumine **v...
# 62488    6834   luc. 8.516  Haec placuit tellus, in **quam** Pharsalica **...
# 62489    6835   luc. 4.229  Sacramenta **tenent**: at vobis vilior **hoc**...
# 62490    6836  luc. 10.101  **Iam** tibi (sed procul **hoc** avertant fata...
# 62491    6837  luc. 10.218  **Quam** nos aestivas a **sole** receperit horas.
# 62492    6838   luc. 6.115  **Quaeque** **per** abrasas utero demittere fa...
# 62493    6839   luc. 4.785  **Quam** fortuna **dabat**: fluvios non ille c...
# 62494    6840   luc. 9.276  **Quam** vitam **veniamque**, libet?   Rapiatu...
# 62495    6841   luc. 2.562  **Quo** **potuit** civem populus perducere liber,
# 62496    6842   luc. 8.835  Tu **quoque**, cum saevo dederis **iam** templ...
# 62497    6843   luc. 7.247  Mens stetit in dubio, **quam** nec sua **fata*...
# 62498    6844   luc. 5.219  Dumque **a** luce sacra, **qua** vidit fata, r...
# 62499    6845  luc. 10.182   **Maiores** docuere tui: **quis** dignior umquam
# 62500    6846   luc. 9.596  **Maiorum**, Fortuna fuit. **Quis** Marte secu...
# 62501    6847   luc. 7.259  Haec, **fato** quae teste probet, **quis** ius...
# 62502    6848   luc. 9.276  **Quam** vitam **veniamque**, libet?   Rapiatu...
# 62503    6849    luc. 5.88  **Quis** terram coeli patitur **deus**, omnia ...
# 62504    6850   luc. 8.274  **Quam** subvertit, opes. Sed me vel **sola** ...
# 62505    6851   luc. 5.741  **Venit** moesta dies, et **quam** nimiumque p...
# 62506    6852   luc. 7.685  **Quamque** fuit laeto **per** tres infida tri...
# 62507    6853   luc. 2.108   Crimine **quo** parvi caedem **potuere** mereri?
# 62508    6854   luc. 7.701  Et soceri miserere **tui**. **Quo** pectore Romam
# 62509    6855   luc. 8.183  Stella, timens Borean: **illa** **quoque** per...
# 62510    6856   luc. 7.245  **Illa** **quoque** in ferrum rabies promptiss...
# 62511    6857   luc. 5.741  **Venit** moesta dies, et **quam** nimiumque p...
# 62512    6858   luc. 2.550  Quamquam, si **qua** fides, his te **quoque** ...
# 62513    6859   luc. 1.334  **Quis** scelerum modus est? Ex hoc te **iam**...
# 62514    6860     luc. 1.8  **Quis** furor, o cives, quae tanta licentia *...
#
#             SOURCE_LOC                                         SOURCE_TXT  \
# 0      ov. am. 1.14.55  Collige cum vultu mentem! **reparabile** **dam...
# 1      ov. am. 2.16.39  Sed Scythiam **Cilicasque** **feros** viridesq...
# 2       ov. am. 1.7.15   Talis periuri promissaque **velaque** **Thesei**
# 3      ov. am. 2.16.25  Non quae **submersis** **ratibus** saturata Ch...
# 4        ov. am. 2.5.9  Felix, qui quod amat defendere **fortiter** **...
# 5       ov. am. 1.8.92   Fit **cito** **per** multas praeda petita manus.
# 6       ov. am. 3.2.65  Maxima iam **vacuo** **praetor** spectacula circo
# 7       ov. am. 2.12.7  Non humiles **muri**, non parvis **oppida** fo...
# 8       ov. am. 1.6.55  Urbe silent tota, vitreoque **madentia** **rore**
# 9       ov. am. 1.6.55  Urbe silent tota, vitreoque **madentia** **rore**
# 10      ov. am. 1.15.1  Quid mihi **Livor** **edax**, ignavos obicis a...
# 11     ov. am. 1.14.23  Cum graciles essent **tamen** et **lanuginis**...
# 12      ov. am. 3.1.32    Densum caesarie **terque** **quaterque** caput.
# 13      ov. am. 3.9.10     **Pectoraque** infesta **tundat** aperta manu!
# 14     ov. am. 2.12.19  Femina silvestris Lapithas **populumque** **bi...
# 15      ov. am. 1.8.69  Parcius exigito pretium, **dum** **retia** ten...
# 16      ov. am. 3.8.37  Aeraque et **argentum** cumque **auro** ponder...
# 17      ov. am. 3.1.16               O **argumenti** lente poeta **tui**?
# 18     ov. am. 1.15.10   Dum rapidas **Simois** in mare volvet **aquas**;
# 19     ov. am. 2.18.30    Legit ab Hippolyto scripta **noverca** **suo**.
# 20      ov. am. 1.11.9  Nec **silicum** venae nec **durum** in pectore...
# 21      ov. am. 3.5.42         **Frigidus** in **viduo** destituere toro.
# 22       ov. am. 1.6.1  Ianitor --- indignum! --- dura **religate** **...
# 23       ov. am. 1.6.1  Ianitor --- indignum! --- dura **religate** **...
# 24       ov. am. 3.1.3  **Fons** sacer in medio speluncaque **pumice**...
# 25     ov. am. 2.12.18     Tyndaris, **Europae** pax **Asiaeque** foret.
# 26     ov. am. 2.12.10  Ex tot in Atridis **pars** **quota** laudis erat?
# 27     ov. am. 2.12.10  Ex tot in Atridis **pars** **quota** laudis erat?
# 28       ov. am. 2.8.7  Num **tamen** **erubui**? num, verbo lapsus in...
# 29     ov. am. 1.10.62  Carmina **quam** **tribuent**, fama perennis e...
# ...                ...                                                ...
# 62485      tib. 3.7.39  Nam **quis** te **maiora** gerit castrisue for...
# 62486       tib. 2.5.1  Phoebe, **faue**: nouus ingreditur **tua** tem...
# 62487     tib. 3.7.111  quem si **quis** **uideat** uetus ut non frege...
# 62488      tib. 1.4.31  **Quam** iacet, infirmae venere ubi **fata** s...
# 62489      tib. 1.5.43  Non facit **hoc** verbis, facie **tenerisque**...
# 62490      tib. 2.2.12        **iam** reor **hoc** ipsos edidicisse deos.
# 62491      tib. 3.18.5  hesterna **quam** te **solum** quod nocte reli...
# 62492      tib. 2.5.69  **quaeque** Aniena sacras Tiburs **per** flumi...
# 62493     tib. 2.5.108  heu heu **quam** multis ars **dedit** ista malum!
# 62494      tib. 1.1.45  **Quam** iuvat inmites **ventos** audire cubantem
# 62495     tib. 1.10.64      **Quo** tenera irato flere puella **potest**.
# 62496      tib. 2.5.51  te **quoque** **iam** uideo, Marti placitura s...
# 62497      tib. 1.4.31  **Quam** iacet, infirmae venere ubi **fata** s...
# 62498      tib. 3.4.62    **A** pereat, didicit fallere si **qua** uirum!
# 62499      tib. 3.7.39  Nam **quis** te **maiora** gerit castrisue for...
# 62500      tib. 3.7.39  Nam **quis** te **maiora** gerit castrisue for...
# 62501      tib. 3.12.7  At tu, sancta, **faue**, neu **quis** diuellat...
# 62502      tib. 1.4.31  **Quam** iacet, infirmae **venere** ubi fata s...
# 62503      tib. 1.6.30  Iussit Amor: contra **quis** ferat arma **deos**?
# 62504      tib. 3.18.5  hesterna **quam** te **solum** quod nocte reli...
# 62505      tib. 1.1.45  **Quam** iuvat inmites **ventos** audire cubantem
# 62506      tib. 2.5.69  **quaeque** Aniena sacras Tiburs **per** flumi...
# 62507     tib. 1.10.64      **Quo** tenera irato flere puella **potest**.
# 62508      tib. 1.9.72     Devoveat pro **quo** remque domumque **tuam**.
# 62509      tib. 1.6.16   Me **quoque** servato, peccet ut **illa** nihil.
# 62510      tib. 1.6.16   Me **quoque** servato, peccet ut **illa** nihil.
# 62511      tib. 1.4.31  **Quam** iacet, infirmae **venere** ubi fata s...
# 62512      tib. 2.5.59  **quaque** patent ortus et **qua** fluitantibu...
# 62513     tib. 1.10.13  Nunc ad bella trahor, et **iam** **quis** fors...
# 62514      tib. 1.6.30  Iussit Amor: contra **quis** **ferat** arma deos?
#
#                        SHARED  SCORE
# 0         damnum; reparabilis     10
# 1           ferus; cilicasque     10
# 2         theseus; uela-uelum     10
# 3             submergo; ratis     10
# 4             audeo; fortiter     10
# 5                  citus; per     10
# 6             uacuus; praetor     10
# 7          murus-mus; oppidum     10
# 8                  ros; madeo     10
# 9                  ros; madeo     10
# 10                edax; liuor     10
# 11              lanugo; tamen     10
# 12                quater; ter      9
# 13              pectus; tundo      9
# 14          biformis; populus      9
# 15                  rete; dum      9
# 16            argentum; aurum      9
# 17           tuus; argumentum      9
# 18               simois; aqua      9
# 19          suo-suus; nouerca      9
# 20               durus; silex      9
# 21     uiduo-uiduus; frigidus      9
# 22      religo; catena-cateno      9
# 23             religo; catena      9
# 24                pumex; fons      9
# 25         europe; asia-asius      9
# 26               pars; quotus      9
# 27               pars; quotus      9
# 28            erubesco; tamen      9
# 29               tribuo; quam      9
# ...                       ...    ...
# 62485            queo; magnus      4
# 62486               for; tuus      4
# 62487             queo; uideo      4
# 62488         fatum-for; quam      4
# 62489              teneo; huc      4
# 62490                iam; huc      4
# 62491   sol-solum-solus; quam      4
# 62492            quisque; per      4
# 62493                do; quam      4
# 62494             uenio; quam      4
# 62495             possum; quo      4
# 62496     iam; quisque-quoque      4
# 62497         fatum-for; quam      4
# 62498            qua; a-aulus      4
# 62499            queo; magnus      4
# 62500            queo; magnus      4
# 62501               queo; for      4
# 62502             uenio; quam      4
# 62503              queo; deus      4
# 62504       solum-solus; quam      4
# 62505             uenio; quam      4
# 62506            quisque; per      4
# 62507             quo; possum      4
# 62508               quo; tuus      4
# 62509    illa; quisque-quoque      4
# 62510    illa; quisque-quoque      4
# 62511             uenio; quam      4
# 62512            qua; quisque      4
# 62513               queo; iam      4
# 62514              queo; fero      4
#
# [62515 rows x 7 columns]

# %%
# SEE http://www.swegler.com/becky/blog/2014/08/06/useful-pandas-snippets/
results['TARGET_AUTHOR'], results['TARGET_BOOK'], results['TARGET_LINE'] = zip(*results['TARGET_LOC'].apply(lambda x: x.split('.')))
results['SOURCE_AUTHOR'] = results['SOURCE_LOC'].apply(lambda x: x[:x.index('.')])
#df['A'].apply(str)

results['TARGET_BOOK'] = results['TARGET_BOOK'].apply(int)
results['TARGET_LINE'] = results['TARGET_LINE'].apply(int)

results
# Out:
#        RESULT   TARGET_LOC                                         TARGET_TXT  \
# 0           1  luc. 10.429  Est operis: visum famulis **reparabile** **dam...
# 1           2   luc. 2.594  Armenios, **Cilicasque** **feros**, Taurosque ...
# 2           3   luc. 2.612   Cecropiae, victum mentitis **Thesea** **velis**.
# 3           4   luc. 4.457  Huc fractas Aquilone **rates** **submersaque**...
# 4           5   luc. 5.322  Detegit imbelles animos nil **fortiter** **ausa**
# 5           6   luc. 7.420  Possedit, **citius** **per** prospera fata cuc...
# 6           7   luc. 3.107  **Praetor** adest: **vacuaeque** loco cessere ...
# 7           8   luc. 4.224     Eruerent, nulli vallarent **oppida** **muri**,
# 8           9   luc. 6.369  Quique nec humentes nebulas, nec **rore** **ma...
# 9          10   luc. 4.316  tunc herbas frondesque terunt, et **rore** **m...
# 10         11   luc. 1.288  **Livor** **edax** tibi cuncta negat: gentesqu...
# 11         12  luc. 10.135    Vix ulla fuscante **tamen** **lanugine** malas.
# 12         13   luc. 5.497  Ausoniam tu solus habes. His **terque** **quat...
# 13         14   luc. 3.733  Non lacrimae cecidere genis, non **pectora** *...
# 14         15   luc. 3.198  Thracius, et **populum** Pholoe mentita **bifo...
# 15         16   luc. 4.439    Aut **dum** dispositis adtollat **retia** varis
# 16         17   luc. 6.404  Fudit et **argentum** flammis, **aurumque** mo...
# 17         18   luc. 8.869     **Argumenta** **tuae**. Veniet felicior aetas,
# 18         19   luc. 9.962  Et **Simoentis** **aquas**, et Graio nobile busto
# 19         20   luc. 4.637  Ille **suis**. Numquam saevae sperare **noverc...
# 20         21   luc. 4.304  Extrahitur, **duris** **silicum** lassata meta...
# 21         22   luc. 5.806   Insomnis. **Viduo** tum primum **frigida** lecto
# 22         23   luc. 4.451  Et laxas fluitare sinit **religatque** **caten...
# 23         24   luc. 2.671  Roboraque immensis late **religare** **catenis**.
# 24         25   luc. 4.300  Aut micuere novi, percusso **pumice**, **fonte...
# 25         26   luc. 2.674  **Europamque** **Asiae**, Sestonque admovit Ab...
# 26         27   luc. 7.489  Sed **quota** **pars** cladis iaculis ferroque...
# 27         28   luc. 1.284  **Pars** **quota** terrarum! Facili si proelia...
# 28         29   luc. 3.112  **Erubuit**, quam Roma pati. **Tamen** exit in...
# 29         30   luc. 4.358  Degere, **quam** **tribuis**: campis prostrata...
# ...       ...          ...                                                ...
# 62485    6831   luc. 7.134   Adtonitus **maiore** metu. **Quis** litora ponto
# 62486    6832   luc. 4.361  Captos ferre **tui**: turba haec sua **fata** ...
# 62487    6833   luc. 9.638  **Quis** timuit? quem, qui recto se lumine **v...
# 62488    6834   luc. 8.516  Haec placuit tellus, in **quam** Pharsalica **...
# 62489    6835   luc. 4.229  Sacramenta **tenent**: at vobis vilior **hoc**...
# 62490    6836  luc. 10.101  **Iam** tibi (sed procul **hoc** avertant fata...
# 62491    6837  luc. 10.218  **Quam** nos aestivas a **sole** receperit horas.
# 62492    6838   luc. 6.115  **Quaeque** **per** abrasas utero demittere fa...
# 62493    6839   luc. 4.785  **Quam** fortuna **dabat**: fluvios non ille c...
# 62494    6840   luc. 9.276  **Quam** vitam **veniamque**, libet?   Rapiatu...
# 62495    6841   luc. 2.562  **Quo** **potuit** civem populus perducere liber,
# 62496    6842   luc. 8.835  Tu **quoque**, cum saevo dederis **iam** templ...
# 62497    6843   luc. 7.247  Mens stetit in dubio, **quam** nec sua **fata*...
# 62498    6844   luc. 5.219  Dumque **a** luce sacra, **qua** vidit fata, r...
# 62499    6845  luc. 10.182   **Maiores** docuere tui: **quis** dignior umquam
# 62500    6846   luc. 9.596  **Maiorum**, Fortuna fuit. **Quis** Marte secu...
# 62501    6847   luc. 7.259  Haec, **fato** quae teste probet, **quis** ius...
# 62502    6848   luc. 9.276  **Quam** vitam **veniamque**, libet?   Rapiatu...
# 62503    6849    luc. 5.88  **Quis** terram coeli patitur **deus**, omnia ...
# 62504    6850   luc. 8.274  **Quam** subvertit, opes. Sed me vel **sola** ...
# 62505    6851   luc. 5.741  **Venit** moesta dies, et **quam** nimiumque p...
# 62506    6852   luc. 7.685  **Quamque** fuit laeto **per** tres infida tri...
# 62507    6853   luc. 2.108   Crimine **quo** parvi caedem **potuere** mereri?
# 62508    6854   luc. 7.701  Et soceri miserere **tui**. **Quo** pectore Romam
# 62509    6855   luc. 8.183  Stella, timens Borean: **illa** **quoque** per...
# 62510    6856   luc. 7.245  **Illa** **quoque** in ferrum rabies promptiss...
# 62511    6857   luc. 5.741  **Venit** moesta dies, et **quam** nimiumque p...
# 62512    6858   luc. 2.550  Quamquam, si **qua** fides, his te **quoque** ...
# 62513    6859   luc. 1.334  **Quis** scelerum modus est? Ex hoc te **iam**...
# 62514    6860     luc. 1.8  **Quis** furor, o cives, quae tanta licentia *...
#
#             SOURCE_LOC                                         SOURCE_TXT  \
# 0      ov. am. 1.14.55  Collige cum vultu mentem! **reparabile** **dam...
# 1      ov. am. 2.16.39  Sed Scythiam **Cilicasque** **feros** viridesq...
# 2       ov. am. 1.7.15   Talis periuri promissaque **velaque** **Thesei**
# 3      ov. am. 2.16.25  Non quae **submersis** **ratibus** saturata Ch...
# 4        ov. am. 2.5.9  Felix, qui quod amat defendere **fortiter** **...
# 5       ov. am. 1.8.92   Fit **cito** **per** multas praeda petita manus.
# 6       ov. am. 3.2.65  Maxima iam **vacuo** **praetor** spectacula circo
# 7       ov. am. 2.12.7  Non humiles **muri**, non parvis **oppida** fo...
# 8       ov. am. 1.6.55  Urbe silent tota, vitreoque **madentia** **rore**
# 9       ov. am. 1.6.55  Urbe silent tota, vitreoque **madentia** **rore**
# 10      ov. am. 1.15.1  Quid mihi **Livor** **edax**, ignavos obicis a...
# 11     ov. am. 1.14.23  Cum graciles essent **tamen** et **lanuginis**...
# 12      ov. am. 3.1.32    Densum caesarie **terque** **quaterque** caput.
# 13      ov. am. 3.9.10     **Pectoraque** infesta **tundat** aperta manu!
# 14     ov. am. 2.12.19  Femina silvestris Lapithas **populumque** **bi...
# 15      ov. am. 1.8.69  Parcius exigito pretium, **dum** **retia** ten...
# 16      ov. am. 3.8.37  Aeraque et **argentum** cumque **auro** ponder...
# 17      ov. am. 3.1.16               O **argumenti** lente poeta **tui**?
# 18     ov. am. 1.15.10   Dum rapidas **Simois** in mare volvet **aquas**;
# 19     ov. am. 2.18.30    Legit ab Hippolyto scripta **noverca** **suo**.
# 20      ov. am. 1.11.9  Nec **silicum** venae nec **durum** in pectore...
# 21      ov. am. 3.5.42         **Frigidus** in **viduo** destituere toro.
# 22       ov. am. 1.6.1  Ianitor --- indignum! --- dura **religate** **...
# 23       ov. am. 1.6.1  Ianitor --- indignum! --- dura **religate** **...
# 24       ov. am. 3.1.3  **Fons** sacer in medio speluncaque **pumice**...
# 25     ov. am. 2.12.18     Tyndaris, **Europae** pax **Asiaeque** foret.
# 26     ov. am. 2.12.10  Ex tot in Atridis **pars** **quota** laudis erat?
# 27     ov. am. 2.12.10  Ex tot in Atridis **pars** **quota** laudis erat?
# 28       ov. am. 2.8.7  Num **tamen** **erubui**? num, verbo lapsus in...
# 29     ov. am. 1.10.62  Carmina **quam** **tribuent**, fama perennis e...
# ...                ...                                                ...
# 62485      tib. 3.7.39  Nam **quis** te **maiora** gerit castrisue for...
# 62486       tib. 2.5.1  Phoebe, **faue**: nouus ingreditur **tua** tem...
# 62487     tib. 3.7.111  quem si **quis** **uideat** uetus ut non frege...
# 62488      tib. 1.4.31  **Quam** iacet, infirmae venere ubi **fata** s...
# 62489      tib. 1.5.43  Non facit **hoc** verbis, facie **tenerisque**...
# 62490      tib. 2.2.12        **iam** reor **hoc** ipsos edidicisse deos.
# 62491      tib. 3.18.5  hesterna **quam** te **solum** quod nocte reli...
# 62492      tib. 2.5.69  **quaeque** Aniena sacras Tiburs **per** flumi...
# 62493     tib. 2.5.108  heu heu **quam** multis ars **dedit** ista malum!
# 62494      tib. 1.1.45  **Quam** iuvat inmites **ventos** audire cubantem
# 62495     tib. 1.10.64      **Quo** tenera irato flere puella **potest**.
# 62496      tib. 2.5.51  te **quoque** **iam** uideo, Marti placitura s...
# 62497      tib. 1.4.31  **Quam** iacet, infirmae venere ubi **fata** s...
# 62498      tib. 3.4.62    **A** pereat, didicit fallere si **qua** uirum!
# 62499      tib. 3.7.39  Nam **quis** te **maiora** gerit castrisue for...
# 62500      tib. 3.7.39  Nam **quis** te **maiora** gerit castrisue for...
# 62501      tib. 3.12.7  At tu, sancta, **faue**, neu **quis** diuellat...
# 62502      tib. 1.4.31  **Quam** iacet, infirmae **venere** ubi fata s...
# 62503      tib. 1.6.30  Iussit Amor: contra **quis** ferat arma **deos**?
# 62504      tib. 3.18.5  hesterna **quam** te **solum** quod nocte reli...
# 62505      tib. 1.1.45  **Quam** iuvat inmites **ventos** audire cubantem
# 62506      tib. 2.5.69  **quaeque** Aniena sacras Tiburs **per** flumi...
# 62507     tib. 1.10.64      **Quo** tenera irato flere puella **potest**.
# 62508      tib. 1.9.72     Devoveat pro **quo** remque domumque **tuam**.
# 62509      tib. 1.6.16   Me **quoque** servato, peccet ut **illa** nihil.
# 62510      tib. 1.6.16   Me **quoque** servato, peccet ut **illa** nihil.
# 62511      tib. 1.4.31  **Quam** iacet, infirmae **venere** ubi fata s...
# 62512      tib. 2.5.59  **quaque** patent ortus et **qua** fluitantibu...
# 62513     tib. 1.10.13  Nunc ad bella trahor, et **iam** **quis** fors...
# 62514      tib. 1.6.30  Iussit Amor: contra **quis** **ferat** arma deos?
#
#                        SHARED  SCORE TARGET_AUTHOR  TARGET_BOOK  TARGET_LINE  \
# 0         damnum; reparabilis     10           luc           10          429
# 1           ferus; cilicasque     10           luc            2          594
# 2         theseus; uela-uelum     10           luc            2          612
# 3             submergo; ratis     10           luc            4          457
# 4             audeo; fortiter     10           luc            5          322
# 5                  citus; per     10           luc            7          420
# 6             uacuus; praetor     10           luc            3          107
# 7          murus-mus; oppidum     10           luc            4          224
# 8                  ros; madeo     10           luc            6          369
# 9                  ros; madeo     10           luc            4          316
# 10                edax; liuor     10           luc            1          288
# 11              lanugo; tamen     10           luc           10          135
# 12                quater; ter      9           luc            5          497
# 13              pectus; tundo      9           luc            3          733
# 14          biformis; populus      9           luc            3          198
# 15                  rete; dum      9           luc            4          439
# 16            argentum; aurum      9           luc            6          404
# 17           tuus; argumentum      9           luc            8          869
# 18               simois; aqua      9           luc            9          962
# 19          suo-suus; nouerca      9           luc            4          637
# 20               durus; silex      9           luc            4          304
# 21     uiduo-uiduus; frigidus      9           luc            5          806
# 22      religo; catena-cateno      9           luc            4          451
# 23             religo; catena      9           luc            2          671
# 24                pumex; fons      9           luc            4          300
# 25         europe; asia-asius      9           luc            2          674
# 26               pars; quotus      9           luc            7          489
# 27               pars; quotus      9           luc            1          284
# 28            erubesco; tamen      9           luc            3          112
# 29               tribuo; quam      9           luc            4          358
# ...                       ...    ...           ...          ...          ...
# 62485            queo; magnus      4           luc            7          134
# 62486               for; tuus      4           luc            4          361
# 62487             queo; uideo      4           luc            9          638
# 62488         fatum-for; quam      4           luc            8          516
# 62489              teneo; huc      4           luc            4          229
# 62490                iam; huc      4           luc           10          101
# 62491   sol-solum-solus; quam      4           luc           10          218
# 62492            quisque; per      4           luc            6          115
# 62493                do; quam      4           luc            4          785
# 62494             uenio; quam      4           luc            9          276
# 62495             possum; quo      4           luc            2          562
# 62496     iam; quisque-quoque      4           luc            8          835
# 62497         fatum-for; quam      4           luc            7          247
# 62498            qua; a-aulus      4           luc            5          219
# 62499            queo; magnus      4           luc           10          182
# 62500            queo; magnus      4           luc            9          596
# 62501               queo; for      4           luc            7          259
# 62502             uenio; quam      4           luc            9          276
# 62503              queo; deus      4           luc            5           88
# 62504       solum-solus; quam      4           luc            8          274
# 62505             uenio; quam      4           luc            5          741
# 62506            quisque; per      4           luc            7          685
# 62507             quo; possum      4           luc            2          108
# 62508               quo; tuus      4           luc            7          701
# 62509    illa; quisque-quoque      4           luc            8          183
# 62510    illa; quisque-quoque      4           luc            7          245
# 62511             uenio; quam      4           luc            5          741
# 62512            qua; quisque      4           luc            2          550
# 62513               queo; iam      4           luc            1          334
# 62514              queo; fero      4           luc            1            8
#
#       SOURCE_AUTHOR
# 0                ov
# 1                ov
# 2                ov
# 3                ov
# 4                ov
# 5                ov
# 6                ov
# 7                ov
# 8                ov
# 9                ov
# 10               ov
# 11               ov
# 12               ov
# 13               ov
# 14               ov
# 15               ov
# 16               ov
# 17               ov
# 18               ov
# 19               ov
# 20               ov
# 21               ov
# 22               ov
# 23               ov
# 24               ov
# 25               ov
# 26               ov
# 27               ov
# 28               ov
# 29               ov
# ...             ...
# 62485           tib
# 62486           tib
# 62487           tib
# 62488           tib
# 62489           tib
# 62490           tib
# 62491           tib
# 62492           tib
# 62493           tib
# 62494           tib
# 62495           tib
# 62496           tib
# 62497           tib
# 62498           tib
# 62499           tib
# 62500           tib
# 62501           tib
# 62502           tib
# 62503           tib
# 62504           tib
# 62505           tib
# 62506           tib
# 62507           tib
# 62508           tib
# 62509           tib
# 62510           tib
# 62511           tib
# 62512           tib
# 62513           tib
# 62514           tib
#
# [62515 rows x 11 columns]

# %%
results = results.loc[results['SCORE'] >= 7]
results
# Out:
#        RESULT   TARGET_LOC                                         TARGET_TXT  \
# 0           1  luc. 10.429  Est operis: visum famulis **reparabile** **dam...
# 1           2   luc. 2.594  Armenios, **Cilicasque** **feros**, Taurosque ...
# 2           3   luc. 2.612   Cecropiae, victum mentitis **Thesea** **velis**.
# 3           4   luc. 4.457  Huc fractas Aquilone **rates** **submersaque**...
# 4           5   luc. 5.322  Detegit imbelles animos nil **fortiter** **ausa**
# 5           6   luc. 7.420  Possedit, **citius** **per** prospera fata cuc...
# 6           7   luc. 3.107  **Praetor** adest: **vacuaeque** loco cessere ...
# 7           8   luc. 4.224     Eruerent, nulli vallarent **oppida** **muri**,
# 8           9   luc. 6.369  Quique nec humentes nebulas, nec **rore** **ma...
# 9          10   luc. 4.316  tunc herbas frondesque terunt, et **rore** **m...
# 10         11   luc. 1.288  **Livor** **edax** tibi cuncta negat: gentesqu...
# 11         12  luc. 10.135    Vix ulla fuscante **tamen** **lanugine** malas.
# 12         13   luc. 5.497  Ausoniam tu solus habes. His **terque** **quat...
# 13         14   luc. 3.733  Non lacrimae cecidere genis, non **pectora** *...
# 14         15   luc. 3.198  Thracius, et **populum** Pholoe mentita **bifo...
# 15         16   luc. 4.439    Aut **dum** dispositis adtollat **retia** varis
# 16         17   luc. 6.404  Fudit et **argentum** flammis, **aurumque** mo...
# 17         18   luc. 8.869     **Argumenta** **tuae**. Veniet felicior aetas,
# 18         19   luc. 9.962  Et **Simoentis** **aquas**, et Graio nobile busto
# 19         20   luc. 4.637  Ille **suis**. Numquam saevae sperare **noverc...
# 20         21   luc. 4.304  Extrahitur, **duris** **silicum** lassata meta...
# 21         22   luc. 5.806   Insomnis. **Viduo** tum primum **frigida** lecto
# 22         23   luc. 4.451  Et laxas fluitare sinit **religatque** **caten...
# 23         24   luc. 2.671  Roboraque immensis late **religare** **catenis**.
# 24         25   luc. 4.300  Aut micuere novi, percusso **pumice**, **fonte...
# 25         26   luc. 2.674  **Europamque** **Asiae**, Sestonque admovit Ab...
# 26         27   luc. 7.489  Sed **quota** **pars** cladis iaculis ferroque...
# 27         28   luc. 1.284  **Pars** **quota** terrarum! Facili si proelia...
# 28         29   luc. 3.112  **Erubuit**, quam Roma pati. **Tamen** exit in...
# 29         30   luc. 4.358  Degere, **quam** **tribuis**: campis prostrata...
# ...       ...          ...                                                ...
# 57512    1858   luc. 2.325    Excitat in **nimios** belli civilis **amores**.
# 57513    1859  luc. 10.436  Cum **procul** **a** muris acies non sparsa ma...
# 57514    1860  luc. 10.436  Cum **procul** **a** muris acies non sparsa ma...
# 57515    1861   luc. 9.649  **E** **coelo** volucres subito cum pondere la...
# 57516    1862   luc. 9.649  **E** **coelo** volucres subito cum pondere la...
# 57517    1863   luc. 9.649  **E** **coelo** volucres subito cum pondere la...
# 57518    1864   luc. 6.642  Haud **procul** **a** Ditis caecis depressa ca...
# 57519    1865   luc. 6.642  Haud **procul** **a** Ditis caecis depressa ca...
# 57520    1866   luc. 5.726  Te **procul** **a** saevi strepitu, Cornelia, ...
# 57521    1867   luc. 5.726  Te **procul** **a** saevi strepitu, Cornelia, ...
# 57522    1868   luc. 3.652  Sed clauso periere mari. -  **tunc** unica **d...
# 57523    1869   luc. 3.375  Haud **procul** **a** muris tumulas surgentis ...
# 57524    1870   luc. 3.375  Haud **procul** **a** muris tumulas surgentis ...
# 57525    1871   luc. 7.582  Ordine nobilitas, venerandaque **corpora** **f...
# 57526    1872   luc. 3.624  Membraque contendit **toto**, **quicumque** ma...
# 57527    1873   luc. 3.463    Sed maior Graio Romana in **corpora** **ferro**
# 57528    1874   luc. 4.143  **Dat** poenas maioris aquae. **Postquam** omn...
# 57529    1875   luc. 4.803  **Ante** **iaces**, quam dira duces Pharsalia ...
# 57530    1876   luc. 1.543  Desperare **diem**: qualem fugiente per **ortus**
# 57531    1877  luc. 10.419  Movit, et in partem **Romani** **venit** Achil...
# 57532    1878    luc. 6.16  **Quemque** **vocat** collem Taulantius incola...
# 57533    1879   luc. 4.579  Ignoratque datos, **ne** **quisquam** serviat,...
# 57534    1880   luc. 3.498  Ultro **acies** inferre parant: **armisque** c...
# 57535    1881   luc. 9.967  Assaraci pressere **domos**, et **templa** deorum
# 57536    1882   luc. 8.395  Sed **tua** sors **levior**, quoniam mors ulti...
# 57537    1883   luc. 6.427  **Aere** Iovis Dodona **sonet**, quis noscere ...
# 57538    1884   luc. 5.760  Cepit, et adtonito cessere **e** pectore **sen...
# 57539    1885   luc. 5.750  **Securos** cepisse pudet cum **coniuge** somnos,
# 57540    1886   luc. 7.314  Quique suos cives, quod **signa** **adversa** ...
# 57541    1887    luc. 4.59  Temporibus, vicere dies: tunc, **sole** **reli...
#
#             SOURCE_LOC                                         SOURCE_TXT  \
# 0      ov. am. 1.14.55  Collige cum vultu mentem! **reparabile** **dam...
# 1      ov. am. 2.16.39  Sed Scythiam **Cilicasque** **feros** viridesq...
# 2       ov. am. 1.7.15   Talis periuri promissaque **velaque** **Thesei**
# 3      ov. am. 2.16.25  Non quae **submersis** **ratibus** saturata Ch...
# 4        ov. am. 2.5.9  Felix, qui quod amat defendere **fortiter** **...
# 5       ov. am. 1.8.92   Fit **cito** **per** multas praeda petita manus.
# 6       ov. am. 3.2.65  Maxima iam **vacuo** **praetor** spectacula circo
# 7       ov. am. 2.12.7  Non humiles **muri**, non parvis **oppida** fo...
# 8       ov. am. 1.6.55  Urbe silent tota, vitreoque **madentia** **rore**
# 9       ov. am. 1.6.55  Urbe silent tota, vitreoque **madentia** **rore**
# 10      ov. am. 1.15.1  Quid mihi **Livor** **edax**, ignavos obicis a...
# 11     ov. am. 1.14.23  Cum graciles essent **tamen** et **lanuginis**...
# 12      ov. am. 3.1.32    Densum caesarie **terque** **quaterque** caput.
# 13      ov. am. 3.9.10     **Pectoraque** infesta **tundat** aperta manu!
# 14     ov. am. 2.12.19  Femina silvestris Lapithas **populumque** **bi...
# 15      ov. am. 1.8.69  Parcius exigito pretium, **dum** **retia** ten...
# 16      ov. am. 3.8.37  Aeraque et **argentum** cumque **auro** ponder...
# 17      ov. am. 3.1.16               O **argumenti** lente poeta **tui**?
# 18     ov. am. 1.15.10   Dum rapidas **Simois** in mare volvet **aquas**;
# 19     ov. am. 2.18.30    Legit ab Hippolyto scripta **noverca** **suo**.
# 20      ov. am. 1.11.9  Nec **silicum** venae nec **durum** in pectore...
# 21      ov. am. 3.5.42         **Frigidus** in **viduo** destituere toro.
# 22       ov. am. 1.6.1  Ianitor --- indignum! --- dura **religate** **...
# 23       ov. am. 1.6.1  Ianitor --- indignum! --- dura **religate** **...
# 24       ov. am. 3.1.3  **Fons** sacer in medio speluncaque **pumice**...
# 25     ov. am. 2.12.18     Tyndaris, **Europae** pax **Asiaeque** foret.
# 26     ov. am. 2.12.10  Ex tot in Atridis **pars** **quota** laudis erat?
# 27     ov. am. 2.12.10  Ex tot in Atridis **pars** **quota** laudis erat?
# 28       ov. am. 2.8.7  Num **tamen** **erubui**? num, verbo lapsus in...
# 29     ov. am. 1.10.62  Carmina **quam** **tribuent**, fama perennis e...
# ...                ...                                                ...
# 57512      tib. 1.8.52       Sed **nimius** luto corpora tingit **amor**.
# 57513      tib. 3.6.25  Sed **procul** **a** nobis hic sit timor, illa...
# 57514     tib. 1.10.66      Is gerat et miti sit **procul** **a** Venere.
# 57515     tib. 3.19.13  Nunc licet **e** **caelo** mittatur amica Tibu...
# 57516       tib. 3.8.2    spectatum **e** **caelo**, si sapis, ipse ueni;
# 57517     tib. 1.10.60       Verberat: **e** **caelo** deripit ille deos.
# 57518      tib. 3.6.25  Sed **procul** **a** nobis hic sit timor, illa...
# 57519     tib. 1.10.66      Is gerat et miti sit **procul** **a** Venere.
# 57520      tib. 3.6.25  Sed **procul** **a** nobis hic sit timor, illa...
# 57521     tib. 1.10.66      Is gerat et miti sit **procul** **a** Venere.
# 57522      tib. 2.6.53  **tunc** tibi, lena, precor **diras**: satis a...
# 57523      tib. 3.6.25  Sed **procul** **a** nobis hic sit timor, illa...
# 57524     tib. 1.10.66      Is gerat et miti sit **procul** **a** Venere.
# 57525      tib. 1.2.27  Nec sinit occurrat quisquam, qui **corpora** *...
# 57526      tib. 2.2.13  nec tibi malueris, **totum** **quaecumque** pe...
# 57527      tib. 1.2.27  Nec sinit occurrat quisquam, qui **corpora** *...
# 57528      tib. 2.5.19  haec **dedit** Aeneae sortes, **postquam** ill...
# 57529      tib. 2.4.22     ne **iaceam** clausam flebilis **ante** domum:
# 57530     tib. 3.7.122   indueras **oriente** **die** duce fertilis anni,
# 57531       tib. 3.1.1       Martis **Romani** festae **uenere** kalendae
# 57532      tib. 2.1.84  uoce: palam pecori, clam sibi **quisque** **uo...
# 57533      tib. 3.6.10    **neue** neget **quisquam** me duce se comitem,
# 57534      tib. 2.3.37  praeda feras **acies** cinxit discordibus **ar...
# 57535      tib. 2.3.22     uenit et a **templis** inrita turba **domum**:
# 57536      tib. 1.9.40     Sed precor exemplo sit **levis** illa **tuo**.
# 57537      tib. 1.8.22    Et faceret, si non **aera** repulsa **sonent**.
# 57538      tib. 1.2.42     Is Venerem **e** rapido **sentiet** esse mari.
# 57539      tib. 3.3.32            **securo** cara **coniuge** posse frui.
# 57540      tib. 3.7.99  **aduersisque** parent acies concurrere **sign...
# 57541      tib. 3.6.40         fleuisti ignoto **sola** **relicta** mari:
#
#                          SHARED  SCORE TARGET_AUTHOR  TARGET_BOOK  \
# 0           damnum; reparabilis     10           luc           10
# 1             ferus; cilicasque     10           luc            2
# 2           theseus; uela-uelum     10           luc            2
# 3               submergo; ratis     10           luc            4
# 4               audeo; fortiter     10           luc            5
# 5                    citus; per     10           luc            7
# 6               uacuus; praetor     10           luc            3
# 7            murus-mus; oppidum     10           luc            4
# 8                    ros; madeo     10           luc            6
# 9                    ros; madeo     10           luc            4
# 10                  edax; liuor     10           luc            1
# 11                lanugo; tamen     10           luc           10
# 12                  quater; ter      9           luc            5
# 13                pectus; tundo      9           luc            3
# 14            biformis; populus      9           luc            3
# 15                    rete; dum      9           luc            4
# 16              argentum; aurum      9           luc            6
# 17             tuus; argumentum      9           luc            8
# 18                 simois; aqua      9           luc            9
# 19            suo-suus; nouerca      9           luc            4
# 20                 durus; silex      9           luc            4
# 21       uiduo-uiduus; frigidus      9           luc            5
# 22        religo; catena-cateno      9           luc            4
# 23               religo; catena      9           luc            2
# 24                  pumex; fons      9           luc            4
# 25           europe; asia-asius      9           luc            2
# 26                 pars; quotus      9           luc            7
# 27                 pars; quotus      9           luc            1
# 28              erubesco; tamen      9           luc            3
# 29                 tribuo; quam      9           luc            4
# ...                         ...    ...           ...          ...
# 57512              amor; nimius      7           luc            2
# 57513           procul; a-aulus      7           luc           10
# 57514           procul; a-aulus      7           luc           10
# 57515                caelum; ex      7           luc            9
# 57516                caelum; ex      7           luc            9
# 57517                caelum; ex      7           luc            9
# 57518           procul; a-aulus      7           luc            6
# 57519           procul; a-aulus      7           luc            6
# 57520           procul; a-aulus      7           luc            5
# 57521           procul; a-aulus      7           luc            5
# 57522               tunc; dirus      7           luc            3
# 57523           procul; a-aulus      7           luc            3
# 57524           procul; a-aulus      7           luc            3
# 57525    ferrum; corporo-corpus      7           luc            7
# 57526          quicumque; totus      7           luc            3
# 57527    ferrum; corporo-corpus      7           luc            3
# 57528              do; postquam      7           luc            4
# 57529               iaceo; ante      7           luc            4
# 57530               dies; orior      7           luc            1
# 57531            uenio; romanus      7           luc           10
# 57532             quisque; uoco      7           luc            6
# 57533          ne-neo; quisquam      7           luc            4
# 57534         arma-armus; acies      7           luc            3
# 57535            domus; templum      7           luc            9
# 57536               tuus; leuis      7           luc            8
# 57537             aer-aes; sono      7           luc            6
# 57538                sentio; ex      7           luc            5
# 57539          coniunx; securus      7           luc            5
# 57540  aduersus-aduerto; signum      7           luc            7
# 57541     relinquo; solum-solus      7           luc            4
#
#        TARGET_LINE SOURCE_AUTHOR
# 0              429            ov
# 1              594            ov
# 2              612            ov
# 3              457            ov
# 4              322            ov
# 5              420            ov
# 6              107            ov
# 7              224            ov
# 8              369            ov
# 9              316            ov
# 10             288            ov
# 11             135            ov
# 12             497            ov
# 13             733            ov
# 14             198            ov
# 15             439            ov
# 16             404            ov
# 17             869            ov
# 18             962            ov
# 19             637            ov
# 20             304            ov
# 21             806            ov
# 22             451            ov
# 23             671            ov
# 24             300            ov
# 25             674            ov
# 26             489            ov
# 27             284            ov
# 28             112            ov
# 29             358            ov
# ...            ...           ...
# 57512          325           tib
# 57513          436           tib
# 57514          436           tib
# 57515          649           tib
# 57516          649           tib
# 57517          649           tib
# 57518          642           tib
# 57519          642           tib
# 57520          726           tib
# 57521          726           tib
# 57522          652           tib
# 57523          375           tib
# 57524          375           tib
# 57525          582           tib
# 57526          624           tib
# 57527          463           tib
# 57528          143           tib
# 57529          803           tib
# 57530          543           tib
# 57531          419           tib
# 57532           16           tib
# 57533          579           tib
# 57534          498           tib
# 57535          967           tib
# 57536          395           tib
# 57537          427           tib
# 57538          760           tib
# 57539          750           tib
# 57540          314           tib
# 57541           59           tib
#
# [14632 rows x 11 columns]

# %%
bc1 = results.loc[results['TARGET_BOOK'] == 1]
bc1 = bc1.sort_index(by=['TARGET_BOOK','TARGET_LINE'], ascending=[True,True])

# %%
#bc3

# %%
line_scores = bc1.groupby('TARGET_LINE').agg({'TARGET_LINE': [np.size]})

# %%
#print(line_scores)

# %%
print(line_scores[line_scores['TARGET_LINE']['size']==line_scores['TARGET_LINE']['size'].max()])
# Out:
#             TARGET_LINE
#                    size
# TARGET_LINE
# 61                   15

# %%
len(line_scores)
# Out:
# 449

# %%
sample = bc1.loc[bc1['TARGET_LINE'] == 61]
sample
# Out:
#        RESULT TARGET_LOC                                         TARGET_TXT  \
# 1434     1435  luc. 1.61  Inque vicem gens omnis **amet**: **Pax** missa...
# 10224     259  luc. 1.61  **Inque** **vicem** gens omnis amet: Pax missa...
# 11046    1081  luc. 1.61  Inque vicem gens **omnis** amet: **Pax** missa...
# 19632     432  luc. 1.61  **Inque** **vicem** gens omnis amet: Pax missa...
# 38603     472  luc. 1.61  Inque vicem gens omnis **amet**: **Pax** missa...
# 42367     525  luc. 1.61  **Inque** **vicem** gens omnis amet: Pax missa...
# 43460    1618  luc. 1.61  Inque vicem gens omnis **amet**: **Pax** missa...
# 43668    1826  luc. 1.61  Inque vicem gens omnis **amet**: **Pax** missa...
# 43743    1901  luc. 1.61  Inque **vicem** gens omnis amet: Pax **missa**...
# 44705    2863  luc. 1.61  Inque vicem **gens** omnis amet: Pax **missa**...
# 44955    3113  luc. 1.61  Inque vicem **gens** omnis amet: Pax missa **p...
# 45143    3301  luc. 1.61  Inque vicem gens omnis amet: Pax missa **per**...
# 45144    3302  luc. 1.61  Inque vicem gens omnis amet: Pax missa **per**...
# 55961     307  luc. 1.61  **Inque** **vicem** gens omnis amet: Pax missa...
# 57441    1787  luc. 1.61  Inque vicem gens **omnis** **amet**: Pax missa...
#
#               SOURCE_LOC                                         SOURCE_TXT  \
# 1434      ov. am. 3.2.50  **Pax** iuvat et media **pace** repertus **amo...
# 10224  ov. ars am. 2.154   **Inque** **vicem** credant res sibi semper agi;
# 11046  ov. ars am. 2.413  Sed lateri ne parce tuo: **pax** **omnis** in ...
# 19632    ov. her. 17.180    **Inque** **vicem** tua me, te mea forma capit;
# 38603   ov. red. am. 283  Hic **amor** et **pax** est, in qua male vulne...
# 42367      prop. 3.25.15  exclusa **inque** **vicem** fastus patiare sup...
# 43460        prop. 3.5.1  **Pacis** **Amor** deus est, **pacem** veneram...
# 43668        prop. 2.2.2        at me composita **pace** fefellit **Amor**.
# 43743      prop. 1.13.10         multarum **miseras** exiget una **vices**.
# 44705       prop. 3.5.45  an ficta in **miseras** descendit fabula **gen...
# 44955       prop. 1.1.29  ferte **per** extremas **gentes** et ferte **p...
# 45143       prop. 4.6.35  aut qualis flexos soluit Pythona **per** **orb...
# 45144      prop. 2.32.53  et cum Deucalionis aquae fluxere **per** **orb...
# 55961        tib. 3.7.93  **inque** **uicem** modo directo contendere pa...
# 57441        tib. 1.5.60     Desere, nam donis vincitur **omnis** **amor**.
#
#                 SHARED  SCORE TARGET_AUTHOR  TARGET_BOOK  TARGET_LINE  \
# 1434          amo; pax      7           luc            1           61
# 10224    uicis; inquam      8           luc            1           61
# 11046       pax; omnis      7           luc            1           61
# 19632    uicis; inquam      8           luc            1           61
# 38603         amo; pax      7           luc            1           61
# 42367    uicis; inquam      8           luc            1           61
# 43460         amo; pax      7           luc            1           61
# 43668         amo; pax      7           luc            1           61
# 43743     mitto; uicis      7           luc            1           61
# 44705      gens; mitto      7           luc            1           61
# 44955        gens; per      7           luc            1           61
# 45143       per; orbis      7           luc            1           61
# 45144  per; orbis-orbo      7           luc            1           61
# 55961    uicis; inquam      8           luc            1           61
# 57441       amo; omnis      7           luc            1           61
#
#       SOURCE_AUTHOR
# 1434             ov
# 10224            ov
# 11046            ov
# 19632            ov
# 38603            ov
# 42367          prop
# 43460          prop
# 43668          prop
# 43743          prop
# 44705          prop
# 44955          prop
# 45143          prop
# 45144          prop
# 55961           tib
# 57441           tib

# %%
# Numpy agg function (obv.) leaves out lines that have no results, so we need to put the zeroes back in
x = list(line_scores.index)
y = list(line_scores['TARGET_LINE']['size'])

b1_len = 695 #length of Book 1
#b5_len = 816
z = []

for i in range(1,b1_len+1):
    if i in x:
        z.append((i,y[x.index(i)]))
    else:
        z.append((i,0))
        
scores = [list(t) for t in zip(*z)]

x = scores[0]
y = scores[1]

#avg = sum(scores[1])/len(scores[1])

# %%
print(len(y))
len(y) - 449
449/695
# Out:
# 695
# 0.6460431654676259

# %%
np.mean(y)
# Out:
# 1.6877697841726618

# %%
fig = plt.figure()
fig.set_size_inches(15,6)
ax = fig.add_subplot(111)
ax.plot(y, color="k")

t =  plt.title('Distribution of Tesserae Matches for Elegists ~ Lucan Book 1',fontsize = 18, fontweight = "bold")
t.set_y(1.05)
fig.subplots_adjust(top=0.85)

ax.xaxis.labelpad = 10 
ax.yaxis.labelpad = 10 

ax.set_xlabel('Line Number', fontsize = 14)
ax.set_ylabel('Count of Matches >=7', fontsize = 14)
plt.show()

# %%
def smooth_list(x,window):
    smoothed_list = []
    for i in range(0,len(x)-window):
        smoothed_list.append(sum(x[i:i+window])/window)
    return smoothed_list

# %%
window = 25
bc5_smooth = smooth_list(y,window)

fig = plt.figure()
fig.set_size_inches(15,3)
ax = fig.add_subplot(111)
ax.plot(bc5_smooth, color="k")

t =  plt.title('Smoothed Distribution of Tesserae Matches for Elegists ~ Lucan Book 5',fontsize = 18, fontweight = "bold")
t.set_y(1.05)
fig.subplots_adjust(top=0.85)

ax.xaxis.labelpad = 10 
ax.yaxis.labelpad = 10 

ax.set_xlabel('Line Number', fontsize = 14)
ax.set_ylabel('Count of Matches >=6', fontsize = 14)
plt.show()

# %%
def add_blank_scores(x,y,length):
# Numpy agg function (obv.) leaves out lines that have no results, so we need to put the zeroes back in

    z = []

    for i in range(1,length+1):
        if i in x:
            z.append((i,y[x.index(i)]))
        else:
            z.append((i,0))
        
    scores = [list(t) for t in zip(*z)]

    return scores[0],scores[1]

# %%
lucan_book_lengths = [695,736,762,824,816,830,872,872,1108,546]

# %%
def plot_allusive_density(results, book, length, window=25, height=4):
    subset = results.loc[results['TARGET_BOOK'] == book]
    subset_scores = subset.groupby('TARGET_LINE').agg({'TARGET_LINE': [np.size],'SCORE':[np.sum]})
    
    subset_scores_index = list(subset_scores.index)
    subset_scores_list = list(subset_scores['TARGET_LINE']['size'])
    x, y = add_blank_scores(subset_scores_index,subset_scores_list,length)
    subset_scores_list = y
    
    subset_scores_list_smoothed = smooth_list(subset_scores_list,window)

    avg = sum(subset_scores_list_smoothed)/len(subset_scores_list)
    
    
    fig = plt.figure()

    fig.set_size_inches(15,3)
    ax = fig.add_subplot(111)
    #ax.axhline(y=avg, color='lightgray')
    ax.plot(subset_scores_list_smoothed, color="black")

    xticks = np.arange(0,max(x),50)
    ax.set_xticks(xticks)

    ax.set_ylim([0, height])
    ax.set_xlim([0, 1108])

    ax.set_title('Smoothed Distribution of Tesserae Matches for Elegists ~ Lucan Book ' + str(book) + ' (Window = 25)', fontsize = 14, fontweight = 'bold')
    ax.set_xlabel('Line Number')
    ax.set_ylabel('Count of Scores >= 7')

    plt.show()

# %%
for i in range(1,11):
    plot_allusive_density(results, i, lucan_book_lengths[i-1],window=1, height=15)

# %%
for i in range(1,11):
    plot_allusive_density(results, i, lucan_book_lengths[i-1],window=25, height=4)
